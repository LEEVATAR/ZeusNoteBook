# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
#1. 데이터
path = './Data/boston/'
x_train = pd.read_csv(path + 'train-data.csv')
y_train = pd.read_csv(path + 'train-target.csv')
x_test = pd.read_csv(path + 'test-data.csv')
y_test = pd.read_csv(path + 'test-target.csv')

print(x_train.shape, y_train.shape) # (333, 12) (333, 1)
print(x_test.shape, y_test.shape)   # (173, 12) (173, 1)
print(x_train.info())
print(y_train.info())
print(x_train.describe())
print(y_train.describe())
# Out:
# (333, 12) (333, 1)
# (173, 12) (173, 1)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 12 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     333 non-null    float64
#  1   zn       333 non-null    float64
#  2   indus    333 non-null    float64
#  3   chas     333 non-null    int64
#  4   nox      333 non-null    float64
#  5   rm       333 non-null    float64
#  6   age      333 non-null    float64
#  7   dis      333 non-null    float64
#  8   rad      333 non-null    int64
#  9   tax      333 non-null    int64
#  10  ptratio  333 non-null    float64
#  11  lstat    333 non-null    float64
# dtypes: float64(9), int64(3)
# memory usage: 31.3 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   medv    333 non-null    float64
# ...

# %%
#2. 모델구성
model = Sequential()
model.add(Dense(10, input_dim=12))
model.add(Dense(20))
model.add(Dense(30))
model.add(Dense(50))
model.add(Dense(30))
model.add(Dense(1))

# %%
#3. 컴파일, 훈련
model.compile(loss = 'mse', optimizer='adam')
model.fit(x_train, y_train, epochs=200, batch_size=1)
# Out:
# Epoch 1/200
# 333/333 [==============================] - 3s 10ms/step - loss: 430.3203
# Epoch 2/200
# 333/333 [==============================] - 4s 13ms/step - loss: 179.2620
# Epoch 3/200
# 333/333 [==============================] - 2s 6ms/step - loss: 156.1684
# Epoch 4/200
# 333/333 [==============================] - 1s 2ms/step - loss: 133.3941
# Epoch 5/200
# 333/333 [==============================] - 1s 2ms/step - loss: 107.6111
# Epoch 6/200
# 333/333 [==============================] - 1s 2ms/step - loss: 93.4716
# Epoch 7/200
# 333/333 [==============================] - 1s 2ms/step - loss: 83.9385
# Epoch 8/200
# 333/333 [==============================] - 1s 2ms/step - loss: 84.2729
# Epoch 9/200
# 333/333 [==============================] - 1s 2ms/step - loss: 81.9772
# Epoch 10/200
# 333/333 [==============================] - 1s 2ms/step - loss: 71.8649
# Epoch 11/200
# 333/333 [==============================] - 1s 2ms/step - loss: 69.7535
# Epoch 12/200
# ...

# %%
#4. 평가,예측
loss = model.evaluate(x_test, y_test)
y_predict = model.predict(x_test)
r2 = r2_score(y_test, y_predict)

print('loss : ', loss)
print('r2 : ', r2)
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 24.7051
# loss :  24.70514678955078
# r2 :  0.7097150614367895
